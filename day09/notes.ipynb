# %%
programming_dictionary = {
    "Bug": "an error that is made",
    "Function": "jamba",
    "boereg": "pastry"
}

print(programming_dictionary["Bug"])

for thing in programming_dictionary:
    print(thing)
# Out:
# an error that is made
# Bug
# Function
# boereg

# %%
student_scores = {
    'Harry': 88,
    'Ron': 78,
    'Hermione': 95,
    'Draco': 75,
    'Neville': 60
}

# #student_grades =
# for student in student_scores:
#     if student_scores[student] <= 70 :
#         print(student + " " + str(student_scores[student]) + " Grade = 'Fail!'' ")
#     elif student_scores[student] >= 71 and student_scores[student] <= 80:
#         print(student + " " + str(student_scores[student]) + " Grade 'Acceptable' ")
#     elif student_scores[student] >= 81 and student_scores[student] <= 90:
#         print(student + " " + str(student_scores[student]) + " Grade = 'Exceeds Expectations' ")
#     elif student_scores[student] >= 91 and student_scores[student] <= 100:
#         print(student + " " + str(student_scores[student]) + " Grade = 'Outstanding' ")

student_grades = {}

for student, score in student_scores.items():
    if score <= 70:
        grade = "Fail"
    elif score <= 80:
        grade = "Acceptable"
    elif score <= 90:
        grade = "Exceeds Expectations"
    else:
        grade = "Outstanding"

    student_grades[student] = grade

print(student_grades)

#This is the scoring criteria: 
#- Scores 91 - 100: Grade = "Outstanding" 
#- Scores 81 - 90: Grade = "Exceeds Expectations" 
#- Scores 71 - 80: Grade = "Acceptable" 
#- Scores 70 or lower: Grade = "Fail"
# Out:
# {'Harry': 'Exceeds Expectations', 'Ron': 'Acceptable', 'Hermione': 'Outstanding', 'Draco': 'Acceptable', 'Neville': 'Fail'}

# %%
capitals = {
    "France:": "Paris",
    "Germany": "Berlin",
}

travel_log = {
    "France": {
        "num_times_visited": 8,
        "cities_visited": ["Paris", "Lille", "Dijon"]
    },
    "Germany": {
        "num_times_visited": 5,
        "cities_visited": ["Berlin", "Hamburg", "Stuttgart"]
        }
}

print(travel_log["Germany"]["cities_visited"][2])
# Out:
# Stuttgart

# %%
bidders = []

print("Welcome to the secret auction program.")

more = "y"

while more == "y":
    bidder_name = input("What is your name? ")
    bidder_bid = int(input("What is your bid? "))

    bidders.append(
        {"bidder_name":bidder_name,
         "bidder_bid": bidder_bid        
        })
    
    more = input("Are there other bidders? (y/n)")


highest_bidder = None
highest_bid = 0

for bidder in bidders:
    if bidder["bidder_bid"] > highest_bid:
        highest_bid = bidder["bidder_bid"]
        highest_bidder = bidder["bidder_name"]

print(f"Winner: {highest_bidder} with {highest_bid}")

print("All bidders: ")
print("_"*50)
sorted_bidders = sorted(bidders, key=lambda x: x["bidder_bid"], reverse=True)

for bidder in sorted_bidders:
    print(f"{bidder["bidder_name"]}: {bidder["bidder_bid"]}")
# Out:
# Welcome to the secret auction program.
# Winner: JARKUS with 23823
# All bidders:
# __________________________________________________
# JARKUS: 23823
# kaan: 48
# joremia: 24
